# %% [markdown]
# <a href="https://www.kaggle.com/code/bryanraybantilan/unicorn-companies-web-scraping?scriptVersionId=94899083" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Web Scraping Using BeautifulSoup

# %%
#import libraries needed
import pandas as pd
import requests
from bs4 import BeautifulSoup

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Here we will web scraping Unicorn companies using BeautifulSoup.
#
# We will use the website [https://www.cbinsights.com/research-unicorn-companies](https://www.cbinsights.com/research-unicorn-companies) for this notebook.

# %%
url = "https://www.cbinsights.com/research-unicorn-companies"
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html5lib')

# %%
unicorn_data = pd.DataFrame(columns=["Company", "Valuation", "Date_Joined", "Country", "City", "Industry", "Select_Investors"])

# First we isolate the body of the table which contains all the information
# Then we loop through each row and find all the column values for each row
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    company = col[0].text
    valuation = col[1].text
    joined = col[2].text
    country = col[3].text
    city = col[4].text
    industry = col[5].text
    investors = col[6].text
    
    # Finally we append the data of each row to the table
    unicorn_data = unicorn_data.append({"Company":company, "Valuation":valuation, "Date_Joined":joined, "Country":country, "City":city, "Industry":industry, "Select_Investors":investors}, ignore_index=True)

# %%
#view webscrap data
unicorn_data
# Out:
#            Company Valuation Date_Joined        Country           City  \
# 0        Bytedance      $140    4/7/2017          China        Beijing
# 1           SpaceX    $100.3   12/1/2012  United States      Hawthorne
# 2            SHEIN      $100    7/3/2018          China       Shenzhen
# 3           Stripe       $95   1/23/2014  United States  San Francisco
# 4           Klarna     $45.6  12/12/2011         Sweden      Stockholm
# ...            ...       ...         ...            ...            ...
# 1100  UPSIDE Foods        $1   4/21/2022  United States       Berkeley
# 1101  Divergent 3D        $1   4/25/2022  United States       Torrance
# 1102        Taxfix        $1   4/28/2022        Germany         Berlin
# 1103          Open        $1    5/2/2022          India      Bengaluru
# 1104      Polarium        $1    5/3/2022         Sweden          Kista
#
#                              Industry  \
# 0             Artificial intelligence
# ...

# %%
#save as csv file
unicorn_data.to_csv('unicorn_data_web_scraped.csv', index=False)
